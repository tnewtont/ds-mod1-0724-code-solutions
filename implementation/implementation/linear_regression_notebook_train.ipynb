# %%
from helper_functions import *

# %%
df1 = load_data(r'C:\Users\trucn\Downloads\house-prices-advanced-regression-techniques\train.csv')

# %%
clean_data(df1)
# Out:
#           Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1.0        60.0       RL         65.0   8450.0   Pave  Grvl      Reg
# 1        2.0        20.0       RL         80.0   9600.0   Pave  Grvl      Reg
# 2        3.0        60.0       RL         68.0  11250.0   Pave  Grvl      IR1
# 3        4.0        70.0       RL         60.0   9550.0   Pave  Grvl      IR1
# 4        5.0        60.0       RL         84.0  14260.0   Pave  Grvl      IR1
# ...      ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456.0        60.0       RL         62.0   7917.0   Pave  Grvl      Reg
# 1456  1457.0        20.0       RL         85.0  13175.0   Pave  Grvl      Reg
# 1457  1458.0        70.0       RL         66.0   9042.0   Pave  Grvl      Reg
# 1458  1459.0        20.0       RL         68.0   9717.0   Pave  Grvl      Reg
# 1459  1460.0        20.0       RL         75.0   9937.0   Pave  Grvl      Reg
#
# ...

# %%
encode_data(df1, 'SalePrice', 'continuous')
# Out:
#           Id  MSSubClass       MSZoning  LotFrontage  LotArea         Street  \
# 0        1.0        60.0  190995.949254         65.0   8450.0  181130.394622
# 1        2.0        20.0  190995.949254         80.0   9600.0  181130.394622
# 2        3.0        60.0  190995.949254         68.0  11250.0  181130.394622
# 3        4.0        70.0  190995.949254         60.0   9550.0  181130.394622
# 4        5.0        60.0  190995.949254         84.0  14260.0  181130.394622
# ...      ...         ...            ...          ...      ...            ...
# 1455  1456.0        60.0  190995.949254         62.0   7917.0  181130.394622
# 1456  1457.0        20.0  190995.949254         85.0  13175.0  181130.394622
# 1457  1458.0        70.0  190995.949254         66.0   9042.0  181130.394622
# 1458  1459.0        20.0  190995.949254         68.0   9717.0  181130.394622
# 1459  1460.0        20.0  190995.949254         75.0   9937.0  181130.394622
#
# ...

# %%
transform_model(df1, 'SalePrice')
# Out:
#             Id  MSSubClass  MSZoning  LotFrontage   LotArea  Street  Alley  \
# 0    -1.000000         0.2       0.0    -0.265787 -0.254076     0.0    0.0
# 1    -0.998629        -0.6       0.0     0.523686  0.030015     0.0    0.0
# 2    -0.997258         0.2       0.0    -0.107893  0.437624     0.0    0.0
# 3    -0.995888         0.4       0.0    -0.528945  0.017663     0.0    0.0
# 4    -0.994517         0.2       0.0     0.734213  1.181201     0.0    0.0
# ...        ...         ...       ...          ...       ...     ...    ...
# 1455  0.994517         0.2       0.0    -0.423682 -0.385746     0.0    0.0
# 1456  0.995888        -0.6       0.0     0.786844  0.913167     0.0    0.0
# 1457  0.997258         0.4       0.0    -0.213156 -0.107831     0.0    0.0
# 1458  0.998629        -0.6       0.0    -0.107893  0.058918     0.0    0.0
# 1459  1.000000        -0.6       0.0     0.260529  0.113266     0.0    0.0
#
# ...

# %%
df1['MSZoning'].value_counts()
# Out:
# MSZoning
#  0.000000         1151
# -64586.201370      218
#  22801.547679       65
# -58859.469327       16
# -114762.130017      10
# Name: count, dtype: int64

# %%
xtrain, xtest, ytrain, ytest = split_data(df1, 'SalePrice', 0.25, 1)

# %%
train_model(xtrain, ytrain, xtest, ytest, alpha_level = 0.0005)
# Out:
# np.float64(0.0028000725804519714)
