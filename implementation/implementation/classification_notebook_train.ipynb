# %%
from helper_functions import *

# %%
df = load_data(r'C:\Users\trucn\Downloads\home-credit-default-risk\application_train.csv')

# %%
clean_data(df)
# Out:
#         SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0         100002.0     1.0         Cash loans           M            N
# 1         100003.0     0.0         Cash loans           F            N
# 2         100004.0     0.0    Revolving loans           M            Y
# 3         100006.0     0.0         Cash loans           F            N
# 4         100007.0     0.0         Cash loans           M            N
# ...            ...     ...                ...         ...          ...
# 307506    456251.0     0.0         Cash loans           M            N
# 307507    456252.0     0.0         Cash loans           F            N
# 307508    456253.0     0.0         Cash loans           F            N
# 307509    456254.0     1.0         Cash loans           F            N
# 307510    456255.0     0.0         Cash loans           F            N
#
#        FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# ...

# %%
with open('clean_data.pickle', "rb") as f:
    imp_dict = pickle.load(f)

# %%
imp_dict
# Out:
# {'AMT_ANNUITY': SimpleImputer(),
#  'AMT_GOODS_PRICE': SimpleImputer(),
#  'OWN_CAR_AGE': SimpleImputer(),
#  'CNT_FAM_MEMBERS': SimpleImputer(),
#  'EXT_SOURCE_1': SimpleImputer(),
#  'EXT_SOURCE_2': SimpleImputer(),
#  'EXT_SOURCE_3': SimpleImputer(),
#  'APARTMENTS_AVG': SimpleImputer(),
#  'BASEMENTAREA_AVG': SimpleImputer(),
#  'YEARS_BEGINEXPLUATATION_AVG': SimpleImputer(),
#  'YEARS_BUILD_AVG': SimpleImputer(),
#  'COMMONAREA_AVG': SimpleImputer(),
#  'ELEVATORS_AVG': SimpleImputer(),
#  'ENTRANCES_AVG': SimpleImputer(),
#  'FLOORSMAX_AVG': SimpleImputer(),
#  'FLOORSMIN_AVG': SimpleImputer(),
#  'LANDAREA_AVG': SimpleImputer(),
#  'LIVINGAPARTMENTS_AVG': SimpleImputer(),
#  'LIVINGAREA_AVG': SimpleImputer(),
#  'NONLIVINGAPARTMENTS_AVG': SimpleImputer(),
#  'NONLIVINGAREA_AVG': SimpleImputer(),
#  'APARTMENTS_MODE': SimpleImputer(),
#  'BASEMENTAREA_MODE': SimpleImputer(),
#  'YEARS_BEGINEXPLUATATION_MODE': SimpleImputer(),
#  'YEARS_BUILD_MODE': SimpleImputer(),
# ...

# %%
encode_data(df, 'TARGET', 'binary')
# Out:
#         SK_ID_CURR  TARGET  NAME_CONTRACT_TYPE  CODE_GENDER  FLAG_OWN_CAR  \
# 0         100002.0     1.0            0.083459     0.101419      0.085002
# 1         100003.0     0.0            0.083459     0.069993      0.085002
# 2         100004.0     0.0            0.054784     0.101419      0.072437
# 3         100006.0     0.0            0.083459     0.069993      0.085002
# 4         100007.0     0.0            0.083459     0.101419      0.085002
# ...            ...     ...                 ...          ...           ...
# 307506    456251.0     0.0            0.083459     0.101419      0.085002
# 307507    456252.0     0.0            0.083459     0.069993      0.085002
# 307508    456253.0     0.0            0.083459     0.069993      0.085002
# 307509    456254.0     1.0            0.083459     0.069993      0.085002
# 307510    456255.0     0.0            0.083459     0.069993      0.085002
#
#         FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# ...

# %%
with open("tar_enc.pickle", "rb") as f:
    tar_encoder = pickle.load(f)

# %%
tar_encoder
# Out:
# TargetEncoder(target_type='binary')

# %%
transform_model(df, 'TARGET')
# Out:
#         SK_ID_CURR  TARGET  NAME_CONTRACT_TYPE  CODE_GENDER  FLAG_OWN_CAR  \
# 0        -1.001140     1.0            0.000000          1.0           0.0
# 1        -1.001135     0.0            0.000000          0.0           0.0
# 2        -1.001129     0.0           -0.028675          1.0          -1.0
# 3        -1.001118     0.0            0.000000          0.0           0.0
# 4        -1.001112     0.0            0.000000          1.0           0.0
# ...            ...     ...                 ...          ...           ...
# 307506    1.000292     0.0            0.000000          1.0           0.0
# 307507    1.000298     0.0            0.000000          0.0           0.0
# 307508    1.000303     0.0            0.000000          0.0           0.0
# 307509    1.000309     1.0            0.000000          0.0           0.0
# 307510    1.000315     0.0            0.000000          0.0           0.0
#
#         FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# ...

# %%
with open("robust_scal.pickle", "rb") as f:
    rob_scal = pickle.load(f) # I got Ran out of input error

# %%
rob_scal
# Out:
# RobustScaler()

# %%
xtrain, xtest, ytrain, ytest = split_data(df, 'TARGET', 0.25, 1)

# %%
train_model(xtrain, ytrain, xtest, ytest)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.92      1.00      0.96     70618
#          1.0       0.47      0.03      0.06      6260
#
#     accuracy                           0.92     76878
#    macro avg       0.69      0.51      0.51     76878
# weighted avg       0.88      0.92      0.88     76878
# np.float64(0.7528329093569804)

# %%
with open("xgbclassifier.pickle", "rb") as f:
 xgbclass_model = pickle.load(f)

# %%
xgbclass_model
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)
